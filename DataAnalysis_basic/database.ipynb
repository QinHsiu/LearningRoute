# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

# %%
conn=create_engine('mysql+pymysql://root:root@localhost,password@IP:3306/test0')

# %%
sql='select * from data_table'
df=pd.read_sql(sql,conn)


def query(table):
    host='localhost'
    user='root'
    password='123456'
    database='qinhsiu'
    port=3306
    conn=create_engine('mysql+pymysql://{}:{}@{}:{}/{}'.format(user,password,host,port,database))
    sql='select * from '+str(table)
    #读取
    result= pd.read_sql(sql,conn)
    #存储
    try:
        result.to_sql('',con=conn,index=False,if_exists='replace')
    except:
        error
    return result
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\qinhsiu\appdata\local\programs\python\python39\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# c:\users\qinhsiu\appdata\local\programs\python\python39\lib\socket.py in create_connection(address, timeout, source_address)
#     821     err = None
# --> 822     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     823         af, socktype, proto, canonname, sa = res
#
# c:\users\qinhsiu\appdata\local\programs\python\python39\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# ...
